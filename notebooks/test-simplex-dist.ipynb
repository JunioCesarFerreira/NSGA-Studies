# %%
import numpy as np

def generate_reference_points(M, p):
    def generate_recursive(points, num_objs, left, total, depth, current_point):
        print("points:", points)
        if depth == num_objs - 1:
            current_point.append(left / total)
            points.append(current_point.copy())
            current_point.pop()
        else:
            for i in range(left + 1):
                current_point.append(i / total)
                generate_recursive(points, num_objs, left - i, total, depth + 1, current_point)
                current_point.pop()
    points = []
    generate_recursive(points, M, p, p, 0, [])
    return np.array(points)

# %%
M = 2
divisions = 6
generate_reference_points(M, divisions)
# Out:
# points: []
# points: []
# points: [[0.0, 1.0]]
# points: [[0.0, 1.0], [0.16666666666666666, 0.8333333333333334]]
# points: [[0.0, 1.0], [0.16666666666666666, 0.8333333333333334], [0.3333333333333333, 0.6666666666666666]]
# points: [[0.0, 1.0], [0.16666666666666666, 0.8333333333333334], [0.3333333333333333, 0.6666666666666666], [0.5, 0.5]]
# points: [[0.0, 1.0], [0.16666666666666666, 0.8333333333333334], [0.3333333333333333, 0.6666666666666666], [0.5, 0.5], [0.6666666666666666, 0.3333333333333333]]
# points: [[0.0, 1.0], [0.16666666666666666, 0.8333333333333334], [0.3333333333333333, 0.6666666666666666], [0.5, 0.5], [0.6666666666666666, 0.3333333333333333], [0.8333333333333334, 0.16666666666666666]]
# array([[0.        , 1.        ],
#        [0.16666667, 0.83333333],
#        [0.33333333, 0.66666667],
#        [0.5       , 0.5       ],
#        [0.66666667, 0.33333333],
#        [0.83333333, 0.16666667],
#        [1.        , 0.        ]])

# %%
M = 3
divisions = 6
generate_reference_points(M, divisions)
# Out:
# points: []
# points: []
# points: []
# points: [[0.0, 0.0, 1.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333], [0.6666666666666666, 0.16666666666666666, 0.16666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333], [0.6666666666666666, 0.16666666666666666, 0.16666666666666666], [0.6666666666666666, 0.3333333333333333, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333], [0.6666666666666666, 0.16666666666666666, 0.16666666666666666], [0.6666666666666666, 0.3333333333333333, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333], [0.6666666666666666, 0.16666666666666666, 0.16666666666666666], [0.6666666666666666, 0.3333333333333333, 0.0], [0.8333333333333334, 0.0, 0.16666666666666666]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333], [0.6666666666666666, 0.16666666666666666, 0.16666666666666666], [0.6666666666666666, 0.3333333333333333, 0.0], [0.8333333333333334, 0.0, 0.16666666666666666], [0.8333333333333334, 0.16666666666666666, 0.0]]
# points: [[0.0, 0.0, 1.0], [0.0, 0.16666666666666666, 0.8333333333333334], [0.0, 0.3333333333333333, 0.6666666666666666], [0.0, 0.5, 0.5], [0.0, 0.6666666666666666, 0.3333333333333333], [0.0, 0.8333333333333334, 0.16666666666666666], [0.0, 1.0, 0.0], [0.16666666666666666, 0.0, 0.8333333333333334], [0.16666666666666666, 0.16666666666666666, 0.6666666666666666], [0.16666666666666666, 0.3333333333333333, 0.5], [0.16666666666666666, 0.5, 0.3333333333333333], [0.16666666666666666, 0.6666666666666666, 0.16666666666666666], [0.16666666666666666, 0.8333333333333334, 0.0], [0.3333333333333333, 0.0, 0.6666666666666666], [0.3333333333333333, 0.16666666666666666, 0.5], [0.3333333333333333, 0.3333333333333333, 0.3333333333333333], [0.3333333333333333, 0.5, 0.16666666666666666], [0.3333333333333333, 0.6666666666666666, 0.0], [0.5, 0.0, 0.5], [0.5, 0.16666666666666666, 0.3333333333333333], [0.5, 0.3333333333333333, 0.16666666666666666], [0.5, 0.5, 0.0], [0.6666666666666666, 0.0, 0.3333333333333333], [0.6666666666666666, 0.16666666666666666, 0.16666666666666666], [0.6666666666666666, 0.3333333333333333, 0.0], [0.8333333333333334, 0.0, 0.16666666666666666], [0.8333333333333334, 0.16666666666666666, 0.0]]
# array([[0.        , 0.        , 1.        ],
#        [0.        , 0.16666667, 0.83333333],
#        [0.        , 0.33333333, 0.66666667],
#        [0.        , 0.5       , 0.5       ],
#        [0.        , 0.66666667, 0.33333333],
#        [0.        , 0.83333333, 0.16666667],
#        [0.        , 1.        , 0.        ],
#        [0.16666667, 0.        , 0.83333333],
#        [0.16666667, 0.16666667, 0.66666667],
#        [0.16666667, 0.33333333, 0.5       ],
#        [0.16666667, 0.5       , 0.33333333],
#        [0.16666667, 0.66666667, 0.16666667],
#        [0.16666667, 0.83333333, 0.        ],
#        [0.33333333, 0.        , 0.66666667],
#        [0.33333333, 0.16666667, 0.5       ],
#        [0.33333333, 0.33333333, 0.33333333],
#        [0.33333333, 0.5       , 0.16666667],
#        [0.33333333, 0.66666667, 0.        ],
#        [0.5       , 0.        , 0.5       ],
#        [0.5       , 0.16666667, 0.33333333],
#        [0.5       , 0.33333333, 0.16666667],
#        [0.5       , 0.5       , 0.        ],
#        [0.66666667, 0.        , 0.33333333],
#        [0.66666667, 0.16666667, 0.16666667],
#        [0.66666667, 0.33333333, 0.        ],
#        [0.83333333, 0.        , 0.16666667],
#        [0.83333333, 0.16666667, 0.        ],
#        [1.        , 0.        , 0.        ]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função fornecida
def generate_reference_points(M, p):
    def generate_recursive(points, num_objs, left, total, depth, current_point):
        if depth == num_objs - 1:
            current_point.append(left / total)
            points.append(current_point.copy())
            current_point.pop()
        else:
            for i in range(left + 1):
                current_point.append(i / total)
                generate_recursive(points, num_objs, left - i, total, depth + 1, current_point)
                current_point.pop()
    points = []
    generate_recursive(points, M, p, p, 0, [])
    return np.array(points)

# Parâmetros
p = 5  # Valor arbitrário, ajustável para maior densidade

# Caso M=2
points_2d = generate_reference_points(2, p)
plt.figure(figsize=(6, 6))
plt.scatter(points_2d[:, 0], points_2d[:, 1], color='blue', label='M=2')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Referência para M=2')
plt.grid(True)
plt.axis('equal')
plt.legend()
plt.show()

# Caso M=3
points_3d = generate_reference_points(3, p)
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points_3d[:, 0], points_3d[:, 1], points_3d[:, 2], color='green', label='M=3')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
ax.set_title('Referência para M=3')
ax.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Função fornecida
def generate_reference_points(M, p):
    def generate_recursive(points, num_objs, left, total, depth, current_point):
        if depth == num_objs - 1:
            current_point.append(left / total)
            points.append(current_point.copy())
            current_point.pop()
        else:
            for i in range(left + 1):
                current_point.append(i / total)
                generate_recursive(points, num_objs, left - i, total, depth + 1, current_point)
                current_point.pop()
    points = []
    generate_recursive(points, M, p, p, 0, [])
    return np.array(points)

# Parâmetros
p = 5  # Valor arbitrário, ajustável para maior densidade

# Caso M=3
points_3d = generate_reference_points(3, p)

# Melhor visualização 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Ajustes de ponto e cor
sc = ax.scatter(
    points_3d[:, 0], 
    points_3d[:, 1], 
    points_3d[:, 2], 
    c=points_3d[:, 2],  # Cor varia com o eixo z
    cmap='viridis',     # Mapa de cores para melhor visual
    s=50,               # Tamanho dos pontos
    alpha=0.8           # Transparência para suavidade
)

# Adicionar barra de cores
cbar = fig.colorbar(sc, ax=ax, pad=0.1)
cbar.set_label('Valor em z', rotation=270, labelpad=15)

# Melhorar rótulos e título
ax.set_xlabel('x1', labelpad=10)
ax.set_ylabel('x2', labelpad=10)
ax.set_zlabel('x3', labelpad=10)
ax.set_title('Referência para M=3', pad=20)

# Ajustar ângulo de visualização
ax.view_init(elev=30, azim=45)

# Adicionar grid e ajustar limites
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_box_aspect([1, 1, 1])  # Proporção do box 3D
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Função fornecida
def generate_reference_points(M, p):
    def generate_recursive(points, num_objs, left, total, depth, current_point):
        if depth == num_objs - 1:
            current_point.append(left / total)
            points.append(current_point.copy())
            current_point.pop()
        else:
            for i in range(left + 1):
                current_point.append(i / total)
                generate_recursive(points, num_objs, left - i, total, depth + 1, current_point)
                current_point.pop()
    points = []
    generate_recursive(points, M, p, p, 0, [])
    return np.array(points)

# Parâmetros
p = 5  # Valor arbitrário para densidade
points_4d = generate_reference_points(4, p)

# Redução de dimensionalidade com PCA
pca = PCA(n_components=3)
points_3d = pca.fit_transform(points_4d)

# Melhor visualização 3D
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')

# Ajustes de ponto e cor
sc = ax.scatter(
    points_3d[:, 0], 
    points_3d[:, 1], 
    points_3d[:, 2], 
    c=points_4d[:, 3],  # Use a quarta dimensão como base para a cor
    cmap='plasma',      # Colormap para melhor visual
    s=50,               # Tamanho dos pontos
    alpha=0.8           # Transparência
)

# Adicionar barra de cores
cbar = fig.colorbar(sc, ax=ax, pad=0.1)
cbar.set_label('Valor em x4 (dimensão original)', rotation=270, labelpad=15)

# Melhorar rótulos e título
ax.set_xlabel('Componente Principal 1', labelpad=10)
ax.set_ylabel('Componente Principal 2', labelpad=10)
ax.set_zlabel('Componente Principal 3', labelpad=10)
ax.set_title('Projeção para M=4 (via PCA)', pad=20)

# Ajustar ângulo de visualização
ax.view_init(elev=30, azim=45)

# Adicionar grid e ajustar proporção
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_box_aspect([1, 1, 1])  # Proporção equilibrada
plt.show()
